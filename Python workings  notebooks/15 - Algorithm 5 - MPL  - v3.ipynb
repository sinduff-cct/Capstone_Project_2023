# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation

# %matplotlib inline 
sns.set(color_codes=True)

# %%
# read in the .csv file - of filtered student_info

data_df = pd.read_csv("filtered_df2_A2.csv")

# %%
#data_df.info()

# %% [markdown]
# ### One-Hot Encoding - categorical data

# %%
# One-Hot Encoding for 'highest_education', 'age_band', 'final_result', 'tenure_band'

data_df_encoded = pd.get_dummies(data_df, columns=['highest_education', 'age_band', 'final_result', 'tenure_band'])

# %%
#data_df_encoded.info()

# %%
# convert the dtype of the recently one-hot encoded columns to int64 from uint8 dtype

columns_to_convert = [
    'highest_education_A Level or Equivalent',
    'highest_education_HE Qualification',
    'highest_education_Lower Than A Level',
    'highest_education_Post Graduate Qualification',
    'age_band_0-35',
    'age_band_35-55',
    'age_band_55<=',
    'final_result_Distinction',
    'final_result_Fail',
    'final_result_Pass',
    'final_result_Withdrawn', 
    'tenure_band_0-5',
    'tenure_band_11-15',
    'tenure_band_16 or more',
    'tenure_band_5-10'
]

# Convert the selected columns to int64 dtype
data_df_encoded[columns_to_convert] = data_df_encoded[columns_to_convert].astype('int64')

# %%
#data_df_encoded.info()

# %% [markdown]
# ### Algorithm 5 - Multilayer Perceptron (MLP)

# %%
# machine learning libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# model layers
from keras.models import Sequential
from keras.layers import Dense

# %%
# divide the dataset into features (X) and the target variable (y)

#id_student
X = data_df_encoded.drop(columns=['studied_credits'])  # drop target variable from the dataframe

y = data_df_encoded['studied_credits']        # id target variable

# %%
# split the data into training and test sets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# define the model
model = Sequential()

# Hidden layer 1 with 50 neurons, and relu as the activation function
model.add(Dense(50, input_dim=X_train.shape[1], activation='relu'))

# Hidden layer 2 with 20 neurons, and relu as the activation function
model.add(Dense(20, activation='relu'))

# Final layer with 1 neuron, and linear as the activation function
model.add(Dense(1, activation='linear'))

# %%
# compile the model
# use 'categorical_crossentropy' for multiclass classification


model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the model
#model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

# Fit the model and get the history object
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 10/10 [==============================] - 1s 33ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 10/10 [==============================] - 0s 8ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 10/10 [==============================] - 0s 9ms/step - loss: 1369.0902 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 10/10 [==============================] - 0s 25ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 10/10 [==============================] - 0s 13ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 10/10 [==============================] - 0s 8ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 7/30
# 10/10 [==============================] - 0s 9ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 8/30
# 10/10 [==============================] - 0s 18ms/step - loss: 1369.0902 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 9/30
# 10/10 [==============================] - 0s 8ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 10/30
# 10/10 [==============================] - 0s 7ms/step - loss: 1369.0902 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 11/30
# 10/10 [==============================] - 0s 7ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 12/30
# 10/10 [==============================] - 0s 7ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 13/30
# 10/10 [==============================] - 0s 7ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 14/30
# 10/10 [==============================] - 0s 7ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 15/30
# 10/10 [==============================] - 0s 7ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 16/30
# 10/10 [==============================] - 0s 7ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 17/30
# 10/10 [==============================] - 0s 7ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 18/30
# 10/10 [==============================] - 0s 7ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 19/30
# 10/10 [==============================] - 0s 8ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 20/30
# 10/10 [==============================] - 0s 7ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 21/30
# 10/10 [==============================] - 0s 7ms/step - loss: 1369.0902 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 22/30
# 10/10 [==============================] - 0s 6ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 23/30
# 10/10 [==============================] - 0s 7ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 24/30
# 10/10 [==============================] - 0s 8ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 25/30
# 10/10 [==============================] - 0s 13ms/step - loss: 1369.0902 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 26/30
# 10/10 [==============================] - 0s 11ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 27/30
# 10/10 [==============================] - 0s 11ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 28/30
# 10/10 [==============================] - 0s 11ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 29/30
# 10/10 [==============================] - 0s 11ms/step - loss: 1369.0902 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00
# Epoch 30/30
# 10/10 [==============================] - 0s 11ms/step - loss: 1369.0903 - accuracy: 0.0000e+00 - val_loss: 1268.0510 - val_accuracy: 0.0000e+00

# %% [markdown]
# ### Plotting the outcome

# %%
# Plotting the accuracy
plt.figure(figsize=(14,5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'])

# %%
# Plotting the loss

plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'])
plt.show()
